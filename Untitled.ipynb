# %%
import json
import pdb

# %%
with open("latest-1000.json") as json_file:
    json_data = json.load(json_file)

# %%
json_data[0]
# Out:
# {u'aliases': {u'bg': [{u'language': u'bg',
#     u'value': u'\u041a\u043e\u0441\u043c\u043e\u0441'},
#    {u'language': u'bg',
#     u'value': u'\u0412\u0441\u0435\u043b\u0435\u043d\u0430'},
#    {u'language': u'bg',
#     u'value': u'\u041a\u043e\u0441\u043c\u0438\u0447\u0435\u0441\u043a\u043e \u043f\u0440\u043e\u0441\u0442\u0440\u0430\u043d\u0441\u0442\u0432\u043e'}],
#   u'ca': [{u'language': u'ca', u'value': u'cosmos'}],
#   u'cs': [{u'language': u'cs', u'value': u've\u0161kerenstvo'},
#    {u'language': u'cs', u'value': u'univerzum'},
#    {u'language': u'cs', u'value': u'kosmos'}],
#   u'de': [{u'language': u'de', u'value': u'Weltall'},
#    {u'language': u'de', u'value': u'All'},
#    {u'language': u'de', u'value': u'Kosmos'},
#    {u'language': u'de', u'value': u'Weltraum'}],
#   u'en': [{u'language': u'en', u'value': u'cosmos'},
#    {u'language': u'en', u'value': u'The Universe'},
#    {u'language': u'en', u'value': u'existence'},
# ...
